# %%
import pandas as pd 

movie_df = pd.read_csv("data/movies.csv")
review_df = pd.read_csv("data/reviews.csv")
movie_df.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
#                                    critics_consensus content_rating  \
# 0  Though it may seem like just another Harry Pot...             PG
# 1  Nicole Holofcener's newest might seem slight i...              R
# 2  Blake Edwards' bawdy comedy may not score a pe...              R
# 3  Sidney Lumet's feature debut is a superbly wri...             NR
# 4  One of Disney's finest live-action adventures,...              G
#
#                                               genres          directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# 2                                    Comedy, Romance      Blake Edwards
# 3                                    Classics, Drama       Sidney Lumet
# 4           Action & Adventure, Drama, Kids & Family  Richard Fleischer
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
# 1                           Nicole Holofcener
# 2                               Blake Edwards
# 3                               Reginald Rose
# 4                                 Earl Felton
#
#                                               actors original_release_date  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Da...            2010-02-12
# 1  Catherine Keener, Amanda Peet, Oliver Platt, R...            2010-04-30
# 2  Dudley Moore, Bo Derek, Julie Andrews, Robert ...            1979-10-05
# 3  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....            1957-04-13
# 4  James Mason, Kirk Douglas, Paul Lukas, Peter L...            1954-01-01
#
#    ...      production_company  tomatometer_status tomatometer_rating  \
# 0  ...        20th Century Fox              Rotten               49.0
# 1  ...  Sony Pictures Classics     Certified-Fresh               87.0
# 2  ...             Waner Bros.               Fresh               67.0
# 3  ...    Criterion Collection     Certified-Fresh              100.0
# 4  ...                  Disney               Fresh               89.0
#
#   tomatometer_count  audience_status  audience_rating audience_count  \
# 0             149.0          Spilled             53.0       254421.0
# 1             142.0          Upright             64.0        11574.0
# 2              24.0          Spilled             53.0        14684.0
# 3              54.0          Upright             97.0       105386.0
# 4              27.0          Upright             74.0        68918.0
#
#    tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                             43                               73
# 1                             44                              123
# 2                              2                               16
# 3                              6                               54
# 4                              5                               24
#
#    tomatometer_rotten_critics_count
# 0                                76
# 1                                19
# 2                                 8
# 3                                 0
# 4                                 3
#
# [5 rows x 22 columns]

# %%
movie_df.loc[1]
# Out:
# rotten_tomatoes_link                                                        m/0878835
# movie_title                                                               Please Give
# movie_info                          Kate (Catherine Keener) and her husband Alex (...
# critics_consensus                   Nicole Holofcener's newest might seem slight i...
# content_rating                                                                      R
# genres                                                                         Comedy
# directors                                                           Nicole Holofcener
# authors                                                             Nicole Holofcener
# actors                              Catherine Keener, Amanda Peet, Oliver Platt, R...
# original_release_date                                                      2010-04-30
# streaming_release_date                                                     2012-09-04
# runtime                                                                          90.0
# production_company                                             Sony Pictures Classics
# tomatometer_status                                                    Certified-Fresh
# tomatometer_rating                                                               87.0
# tomatometer_count                                                               142.0
# audience_status                                                               Upright
# audience_rating                                                                  64.0
# audience_count                                                                11574.0
# tomatometer_top_critics_count                                                      44
# tomatometer_fresh_critics_count                                                   123
# tomatometer_rotten_critics_count                                                   19
# Name: 1, dtype: object

# %%
from infer_llm import create_session, invoke_query

rag_chain = create_session()
response, ids = invoke_query(rag_chain, "recommend me some movies about heros. I especially like actions.")
print("Answer:\n", response)
print()
print(ids)
# Out:
# c:\대학과제\비정형\project\infer_llm.py:34: LangChainDeprecationWarning: The class `ChatPerplexity` was deprecated in LangChain 0.3.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-perplexity package and should be used instead. To use it run `pip install -U :class:`~langchain-perplexity` and import as `from :class:`~langchain_perplexity import ChatPerplexity``.
#   model = ChatPerplexity(model="sonar", pplx_api_key=os.environ.get("PPLX_API_KEY"), temperature=temperature)
# c:\대학과제\비정형\project\retriever.py:37: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_func = HuggingFaceEmbeddings(model_name=embedding_model)
# c:\대학과제\비정형\project\retriever.py:38: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectordb = Chroma(persist_directory=load_dir, embedding_function=embedding_func)
# Answer:
#  Here are three recommended movies about heroes with strong action elements from your list:
#
# 1. **Last Action Hero**
# This movie features a young boy who enters the fictional world of his favorite action hero, Jack Slater, a tough cop played by Arnold Schwarzenegger. It combines action, adventure, and comedy with plenty of thrilling sequences as they battle a villain who escapes into the real world, making it a perfect fit for action hero fans[2][3][5].
#
# 2. **Hero**
# Set in ancient China, this visually stunning martial arts epic follows a nameless fighter who recounts his battles against deadly assassins. The film is rich in action and drama, showcasing intense fight choreography and heroic themes, ideal for viewers who appreciate classic and artful action hero stories[Context].
#
# 3. **Sidekick**
# This comedy and sci-fi film explores the idea of heroism through the story of Victor, who gains extraordinary abilities and is trained to become a real-life superhero. It offers a fresh take on what it means to be a hero, blending humor with superhero action elements[Context].
#
# These selections balance strong action with compelling hero narratives, matching your interest in action-packed hero movies.
#
# ['m/last_action_hero', 'm/hero', 'm/sidekick']
